# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/Fruit.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('finish')
# Out:
# finish

# %%
#Importing keras libraries and packages

from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import MaxPooling2D

# %%
#step1 Initializing CNN
classifier = Sequential()

# step2 adding 1st Convolution layer and Pooling layer
classifier.add(Convolution2D(32,(3,3),input_shape = (64,64,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size = (2, 2)))

# step3 adding 2nd convolution layer and polling layer
classifier.add(Convolution2D(32,(3,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size = (2, 2)))


#step4 Flattening the layers
classifier.add(Flatten())

# %%
#step5 Full_Connection

classifier.add(Dense(units=32,activation = 'relu'))

classifier.add(Dense(units=64,activation = 'relu'))

classifier.add(Dense(units=128,activation = 'relu'))

classifier.add(Dense(units=256,activation = 'relu'))

classifier.add(Dense(units=256,activation = 'relu'))

classifier.add(Dense(units=6,activation = 'softmax'))

# %%
#step6 Compiling CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
#step7 Fitting CNN to images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255, # To rescaling the image in range of [0,1]
                                   shear_range = 0.2, # To randomly shear the images 
                                   zoom_range = 0.2, # To randomly zoom the images
                                   horizontal_flip = True) #  for randomly flipping half of the images horizontally 

test_datagen = ImageDataGenerator(rescale = 1./255)
print("\nTraining the data...\n")
training_set = train_datagen.flow_from_directory('/content/Fruit_Recognition/train',
                                                target_size=(64,64),
                                                batch_size=12, #Total no. of batches
                                                class_mode='categorical')

test_set = test_datagen.flow_from_directory('/content/Fruit_Recognition/test',
                                            target_size=(64,64),
                                            batch_size=12,
                                            class_mode='categorical')
# Out:
# Training the data...
#
# Found 1212 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.

# %%
classifier.fit_generator(training_set,
                         steps_per_epoch=101, # Total training images
                         epochs = 20, # Total no. of epochs
                         validation_data = test_set,
                         validation_steps= 25) # Total testing images
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# 101/101 [==============================] - 31s 101ms/step - loss: 1.5455 - accuracy: 0.3540 - val_loss: 1.2662 - val_accuracy: 0.4500
# Epoch 2/20
# 101/101 [==============================] - 10s 98ms/step - loss: 1.0906 - accuracy: 0.5487 - val_loss: 0.8464 - val_accuracy: 0.6667
# Epoch 3/20
# 101/101 [==============================] - 10s 97ms/step - loss: 0.9347 - accuracy: 0.6130 - val_loss: 0.9107 - val_accuracy: 0.5500
# Epoch 4/20
# 101/101 [==============================] - 10s 98ms/step - loss: 0.8476 - accuracy: 0.6394 - val_loss: 0.6725 - val_accuracy: 0.6933
# Epoch 5/20
# 101/101 [==============================] - 10s 98ms/step - loss: 0.7640 - accuracy: 0.7046 - val_loss: 0.6211 - val_accuracy: 0.7500
# Epoch 6/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.6962 - accuracy: 0.7384 - val_loss: 0.6596 - val_accuracy: 0.7133
# Epoch 7/20
# 101/101 [==============================] - 10s 100ms/step - loss: 0.5689 - accuracy: 0.8003 - val_loss: 0.5928 - val_accuracy: 0.7767
# Epoch 8/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.5839 - accuracy: 0.7913 - val_loss: 0.6894 - val_accuracy: 0.7033
# Epoch 9/20
# 101/101 [==============================] - 10s 102ms/step - loss: 0.5219 - accuracy: 0.8144 - val_loss: 0.4104 - val_accuracy: 0.8600
# Epoch 10/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.4553 - accuracy: 0.8416 - val_loss: 0.5183 - val_accuracy: 0.7733
# Epoch 11/20
# 101/101 [==============================] - 10s 101ms/step - loss: 0.4716 - accuracy: 0.8284 - val_loss: 0.4424 - val_accuracy: 0.8033
# Epoch 12/20
# 101/101 [==============================] - 10s 100ms/step - loss: 0.4061 - accuracy: 0.8614 - val_loss: 0.3614 - val_accuracy: 0.8667
# Epoch 13/20
# 101/101 [==============================] - 10s 100ms/step - loss: 0.4565 - accuracy: 0.8424 - val_loss: 0.3403 - val_accuracy: 0.8767
# Epoch 14/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.4231 - accuracy: 0.8548 - val_loss: 0.4806 - val_accuracy: 0.7767
# Epoch 15/20
# 101/101 [==============================] - 10s 101ms/step - loss: 0.3500 - accuracy: 0.8828 - val_loss: 0.3940 - val_accuracy: 0.8500
# Epoch 16/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.3641 - accuracy: 0.8787 - val_loss: 0.3263 - val_accuracy: 0.8767
# Epoch 17/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.3434 - accuracy: 0.8837 - val_loss: 0.4247 - val_accuracy: 0.8200
# Epoch 18/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.3078 - accuracy: 0.8870 - val_loss: 0.3436 - val_accuracy: 0.8667
# Epoch 19/20
# 101/101 [==============================] - 10s 99ms/step - loss: 0.2938 - accuracy: 0.8969 - val_loss: 0.4844 - val_accuracy: 0.8367
# Epoch 20/20
# 101/101 [==============================] - 10s 100ms/step - loss: 0.3642 - accuracy: 0.8680 - val_loss: 0.4550 - val_accuracy: 0.8167

# %%
#step8 saving model 

classifier.save("Fruit_model_CNN.h5")
